# %%
import csv
file = open('/Users/ricole/Desktop/GR5702-g15-FinalProject/2019_Iowa_Liquor_Sales.csv')
csvreader = csv.reader(file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/ricole/Desktop/Leetcode/Leetcode-Note/final_project_data.ipynb 单元格 1 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/ricole/Desktop/Leetcode/Leetcode-Note/final_project_data.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> csvreader = csv.reader(file)
#       <a href='vscode-notebook-cell:/Users/ricole/Desktop/Leetcode/Leetcode-Note/final_project_data.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> for i in range(10):
# ----> <a href='vscode-notebook-cell:/Users/ricole/Desktop/Leetcode/Leetcode-Note/final_project_data.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a>     print(csvreader[i])
#
# TypeError: '_csv.reader' object is not subscriptable

# %%
header = []
header = next(csvreader)
header
# Out:
# ['\ufeffInvoice/Item Number',
#  'Date',
#  'Store Number',
#  'Store Name',
#  'Address',
#  'City',
#  'Zip Code',
#  'Store Location',
#  'County Number',
#  'County',
#  'Category',
#  'Category Name',
#  'Vendor Number',
#  'Vendor Name',
#  'Item Number',
#  'Item Description',
#  'Pack',
#  'Bottle Volume (ml)',
#  'State Bottle Cost',
#  'State Bottle Retail',
#  'Bottles Sold',
#  'Sale (Dollars)',
#  'Volume Sold (Liters)',
#  'Volume Sold (Gallons)']

# %%
import pandas as pd
  
# making data frame from csv file 
data = pd.read_csv("/Users/ricole/Desktop/GR5702-g15-FinalProject/2019_Iowa_Liquor_Sales.csv")
  
# generating one row 
row1 = data.sample(n = 100000)
  
# display
row1
# Out:
# /var/folders/j_/84vxm1c91vd09r8t20wzdpkm0000gn/T/ipykernel_8431/101992603.py:4: DtypeWarning: Columns (18,19,20,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/Users/ricole/Desktop/GR5702-g15-FinalProject/2019_Iowa_Liquor_Sales.csv")
#         Invoice/Item Number        Date  Store Number  \
# 2042188     INV-23253200050  11/15/2019          2505
# 1489672     INV-21414600011  08/22/2019          4668
# 1128648     INV-20257400079  06/27/2019          2106
# 1163485     INV-20382500068  07/03/2019          2521
# 2231187     INV-23873100014  12/12/2019          3644
# ...                     ...         ...           ...
# 9146        INV-16684100019  01/02/2019          2636
# 1587743     INV-21714600034  09/05/2019          2642
# 908363      INV-19636800004  05/28/2019          4184
# 2216069     INV-23792300008  12/10/2019          4657
# 1673673     INV-22015300181  09/19/2019          2588
#
# ...

# %%
row1.to_csv('/Users/ricole/Desktop/GR5702-g15-FinalProject/2019_Iowa_Liquor_Sales_sample.csv', index=False)
